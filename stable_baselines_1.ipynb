# %%
import random
import time
import numpy as np
import math 
import cv2
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3.common.env_checker import check_env
from stable_baselines3 import PPO 
from typing import Callable
import os
import carla
# Out:
# 2024-05-05 13:03:30.049218: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-05 13:03:30.119684: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-05 13:03:30.441484: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/gp-coopperc/anaconda3/envs/Tensor/lib/python3.9/site-packages/cv2/../../lib64:/usr/local/cuda-11.3/lib64:
# 2024-05-05 13:03:30.441519: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/gp-coopperc/anaconda3/envs/Tensor/lib/python3.9/site-packages/cv2/../../lib64:/usr/local/cuda-11.3/lib64:
# 2024-05-05 13:03:30.441522: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
SECONDS_PER_EPISODE = 25

N_CHANNELS = 3
HEIGHT = 250
WIDTH = 250

FIXED_DELTA_SECONDS = 0.2

SHOW_PREVIEW = True

# %%
class CarEnv(gym.Env):
    SHOW_CAM = SHOW_PREVIEW
    STEER_AMT = 1.0
    im_width = WIDTH
    im_height = HEIGHT
    front_camera = None
    CAMERA_POS_Z = 1.3 
    CAMERA_POS_X = 1.4
    def __init__(self):
        super(CarEnv, self).__init__()
        
        self.action_space = spaces.MultiDiscrete([ 9, 4 ])

        self.observation_space = spaces.Box(low=0.0, high=255.0,
                                            shape=(HEIGHT, WIDTH, N_CHANNELS), dtype=np.uint8)
        
        self.client = carla.Client("localhost", 2000)
        self.client.set_timeout(4.0)
        self.world = self.client.get_world()

        self.settings = self.world.get_settings()
        self.settings.no_rendering_mode = True
        #self.settings.synchronous_mode = False
        self.settings.fixed_delta_seconds = FIXED_DELTA_SECONDS
        self.world.apply_settings(self.settings)
        self.blueprint_library = self.world.get_blueprint_library()
        self.model_3 = self.blueprint_library.filter("model3")[0]
        
    def reset(self, seed=None, options=None):
        self.collision_hist = []
        self.actor_list = []
        self.transform = random.choice(self.world.get_map().get_spawn_points())

        self.vehicle = None
        while self.vehicle is None:
            try:
        # connect
                self.vehicle = self.world.spawn_actor(self.model_3, self.transform)
            except:
                pass
        self.actor_list.append(self.vehicle)
        self.initial_location = self.vehicle.get_location()
        self.sem_cam = self.blueprint_library.find('sensor.camera.semantic_segmentation')
        self.sem_cam.set_attribute("image_size_x", f"{self.im_width}")
        self.sem_cam.set_attribute("image_size_y", f"{self.im_height}")
        self.sem_cam.set_attribute("fov", f"90")


        camera_init_trans = carla.Transform(carla.Location(z=self.CAMERA_POS_Z,x=self.CAMERA_POS_X))
        self.sensor = self.world.spawn_actor(self.sem_cam, camera_init_trans, attach_to=self.vehicle)
        self.actor_list.append(self.sensor)
        self.sensor.listen(lambda data: self.process_img(data))

        self.vehicle.apply_control(carla.VehicleControl(throttle=0.0, brake=0.0))
        time.sleep(2) #not detect a collision when the car spawns/falls from sky.
        # showing camera at the spawn point
        if self.SHOW_CAM:
            cv2.namedWindow('Sem Camera',cv2.WINDOW_AUTOSIZE)
            cv2.imshow('Sem Camera', self.front_camera)
            cv2.waitKey(1)
        colsensor = self.blueprint_library.find("sensor.other.collision")
        self.colsensor = self.world.spawn_actor(colsensor, camera_init_trans, attach_to=self.vehicle)
        self.actor_list.append(self.colsensor)
        self.colsensor.listen(lambda event: self.collision_data(event))

        while self.front_camera is None:
            time.sleep(0.01)#Just in case car takes any longer, because we need to be certain the car is done falling from the sky on spawn.

        self.episode_start = time.time()
        #self.steering_lock = False
        #self.steering_lock_start = None # this is to count time in steering lock and start penalising for long time in steering lock
        self.step_counter = 0
        self.vehicle.apply_control(carla.VehicleControl(throttle=0.0, brake=0.0))
        
        observation = self.front_camera

        return observation.astype(np.uint8), {}
    
    def step(self, action):
        self.step_counter +=1
        steer = action[0]
        throttle = action[1]
        # map steering actions
        if steer ==0:
            steer = - 0.9
        elif steer ==1:
            steer = -0.25
        elif steer ==2:
            steer = -0.1
        elif steer ==3:
            steer = -0.05
        elif steer ==4:
            steer = 0.0 
        elif steer ==5:
            steer = 0.05
        elif steer ==6:
            steer = 0.1
        elif steer ==7:
            steer = 0.25
        elif steer ==8:
            steer = 0.9
        # map throttle and apply steer and throttle
        if throttle == 0:
            self.vehicle.apply_control(carla.VehicleControl(throttle=0.0, steer=steer, brake = 1.0))
        elif throttle == 1:
            self.vehicle.apply_control(carla.VehicleControl(throttle=0.3, steer=steer, brake = 0.0))
        elif throttle == 2:
            self.vehicle.apply_control(carla.VehicleControl(throttle=0.7, steer=steer, brake = 0.0))
        else:
            self.vehicle.apply_control(carla.VehicleControl(throttle=1.0, steer=steer, brake = 0.0))


        v = self.vehicle.get_velocity()
        kmh = int(3.6 * math.sqrt(v.x**2 + v.y**2 + v.z**2))

        #distance_travelled = self.initial_location.distance(self.vehicle.get_location())

        # storing camera to return at the end in case the clean-up function destroys it
        cam = self.front_camera
        # showing image
        if self.SHOW_CAM:
            cv2.imshow('Sem Camera', cam)
            cv2.waitKey(1)

        # start defining reward from each step
        reward = 0
        done = False
        #punish for collision
        if len(self.collision_hist) != 0:
            done = True
            reward = reward - 300
            self.cleanup()
        #reward for acceleration
        if kmh < 15:
            reward = reward - 3
        elif kmh <25:
            reward = reward - 2
        elif kmh <50:
            reward = reward - 1
        elif kmh>120:
            reward = reward - 10 #punish for going too fast
        else:
            reward = reward + 1

        # check for episode duration
        if self.episode_start + SECONDS_PER_EPISODE < time.time():
            done = True
            self.cleanup()
        
        observation = cam
        
        return observation.astype(np.uint8), reward, done, False, {}

    def cleanup(self):
        for sensor in self.world.get_actors().filter('*sensor*'):      
            sensor.destroy()
        for actor in self.world.get_actors().filter('*vehicle*'):
                    
            actor.destroy()
            
        cv2.destroyAllWindows()
        
    def process_img(self, image):
        image.convert(carla.ColorConverter.CityScapesPalette)
        i = np.array(image.raw_data)
        i = i.reshape((self.im_height, self.im_width, 4))[:, :, :3] # this is to ignore the 4th Alpha channel - up to 3
        self.front_camera = i/255.0

    def collision_data(self, event):
        self.collision_hist.append(event)

# %%
#env = CarEnv()

#check_env(env, warn=True, skip_render_check = True)

# %%
models_dir = f"models/{int(time.time())}/"
logdir = f"logs/{int(time.time())}/"

if not os.path.exists(models_dir):
    os.makedirs(models_dir)

if not os.path.exists(logdir):
    os.makedirs(logdir)


env = CarEnv()

env.reset()

model = PPO('MlpPolicy', env, verbose=1,learning_rate=0.001,tensorboard_log=logdir)

TIMESTEPS = 500_000 # individual steps
iters = 0
while iters<4:  # how many training iterations you want
    iters += 1
    print('Iteration ', iters,' is to start...')
    model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name=f"PPO" )
    print('Iteration ', iters,' has been trained')
    model.save(f"{models_dir}/{TIMESTEPS*iters}")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Iteration  1  is to start...
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 25 (sensor.camera.semantic_segmentation)
# Logging to logs/1714903411/PPO_0
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 26 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 28 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 29 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 31 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 32 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 34 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 35 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 37 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 38 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 40 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 41 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 43 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 44 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 46 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 47 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 49 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 50 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 52 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 53 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 55 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 56 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 58 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 59 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 61 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 62 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 64 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 65 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 67 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 68 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 70 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 71 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 73 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 74 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 76 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 77 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 79 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 80 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 82 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 83 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 85 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 86 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 88 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 89 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 91 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 92 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 94 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 95 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 97 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 98 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 100 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 101 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 103 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 104 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 106 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 107 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 109 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 110 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 112 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 113 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 115 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 116 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 118 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 119 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 121 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 122 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 124 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 125 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 127 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 128 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 130 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 131 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 133 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 134 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 136 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 137 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 139 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 140 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 142 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 143 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 145 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 146 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 148 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 149 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 151 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 152 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 154 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 155 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 157 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 158 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 160 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 161 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 163 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 164 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 166 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 167 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 169 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 170 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 172 (sensor.camera.semantic_segmentation)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.6     |
# |    ep_rew_mean     | -404     |
# | time/              |          |
# |    fps             | 18       |
# |    iterations      | 1        |
# |    time_elapsed    | 113      |
# |    total_timesteps | 2048     |
# ---------------------------------
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 173 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 175 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 176 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 178 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 179 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 181 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 182 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 184 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 185 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 187 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 188 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 190 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 191 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 193 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 194 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 196 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 197 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 199 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 200 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 202 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 203 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 205 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 206 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 208 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 209 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 211 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 212 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 214 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 215 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 217 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 218 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 220 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 221 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 223 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 224 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 226 (sensor.camera.semantic_segmentation)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 227 (sensor.other.collision)
# WARNING: sensor object went out of the scope but the sensor is still alive in the simulation: Actor 229 (sensor.camera.semantic_segmentation)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 22
#      20 iters += 1
#      21 print('Iteration ', iters,' is to start...')
# ---> 22 model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name=f"PPO" )
#      23 print('Iteration ', iters,' has been trained')
#      24 model.save(f"{models_dir}/{TIMESTEPS*iters}")
#
# File ~/anaconda3/envs/Tensor/lib/python3.9/site-packages/stable_baselines3/ppo/ppo.py:315, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     306 def learn(
#     307     self: SelfPPO,
#     308     total_timesteps: int,
#    (...)
#     313     progress_bar: bool = False,
#     314 ) -> SelfPPO:
# --> 315     return super().learn(
#     316         total_timesteps=total_timesteps,
#     317         callback=callback,
#     318         log_interval=log_interval,
#     319         tb_log_name=tb_log_name,
#     320         reset_num_timesteps=reset_num_timesteps,
#     321         progress_bar=progress_bar,
#     322     )
#
# File ~/anaconda3/envs/Tensor/lib/python3.9/site-packages/stable_baselines3/common/on_policy_algorithm.py:300, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     297 assert self.env is not None
#     299 while self.num_timesteps < total_timesteps:
# --> 300     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     302     if not continue_training:
#     303         break
#
# File ~/anaconda3/envs/Tensor/lib/python3.9/site-packages/stable_baselines3/common/on_policy_algorithm.py:195, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     190     else:
#     191         # Otherwise, clip the actions to avoid out of bound error
#     192         # as we are sampling from an unbounded Gaussian distribution
#     193         clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 195 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     197 self.num_timesteps += env.num_envs
#     199 # Give access to local variables
#
# File ~/anaconda3/envs/Tensor/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File ~/anaconda3/envs/Tensor/lib/python3.9/site-packages/stable_baselines3/common/vec_env/vec_transpose.py:97, in VecTransposeImage.step_wait(self)
#      96 def step_wait(self) -> VecEnvStepReturn:
# ---> 97     observations, rewards, dones, infos = self.venv.step_wait()
#      99     # Transpose the terminal observations
#     100     for idx, done in enumerate(dones):
#
# File ~/anaconda3/envs/Tensor/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:70, in DummyVecEnv.step_wait(self)
#      67     if self.buf_dones[env_idx]:
#      68         # save final observation where user can get it, then reset
#      69         self.buf_infos[env_idx]["terminal_observation"] = obs
# ---> 70         obs, self.reset_infos[env_idx] = self.envs[env_idx].reset()
#      71     self._save_obs(env_idx, obs)
#      72 return (self._obs_from_buf(), np.copy(self.buf_rews), np.copy(self.buf_dones), deepcopy(self.buf_infos))
#
# File ~/anaconda3/envs/Tensor/lib/python3.9/site-packages/stable_baselines3/common/monitor.py:83, in Monitor.reset(self, **kwargs)
#      81         raise ValueError(f"Expected you to pass keyword argument {key} into reset")
#      82     self.current_reset_info[key] = value
# ---> 83 return self.env.reset(**kwargs)
#
# Cell In[3], line 55, in CarEnv.reset(self, seed, options)
#      52 self.sensor.listen(lambda data: self.process_img(data))
#      54 self.vehicle.apply_control(carla.VehicleControl(throttle=0.0, brake=0.0))
# ---> 55 time.sleep(2) #not detect a collision when the car spawns/falls from sky.
#      56 # showing camera at the spawn point
#      57 if self.SHOW_CAM:
#
# KeyboardInterrupt:
